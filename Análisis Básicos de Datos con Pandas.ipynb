# %%
import pandas as pd

df1 = pd.read_csv("https://raw.githubusercontent.com/NelsonJavierAguilera/Proyectos_Personales/main/AnyConv.com__ventasTotalesv2.csv")

df1
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 0     1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1     1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2     1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3     1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4     1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# ..         ...               ...    ...                ...          ...
# 455  1/31/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  1/31/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  1/31/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  1/31/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  1/31/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades  Ganancia
# 0           6     18.00
# 1           8      3.84
# 2           3      6.30
# ...

# %%
df1.Vendedor.value_counts(ascending=True, dropna=False)
# Out:
# Boris Stanford      69
# Dustin Gee          70
# Trevor Snodgrass    75
# Desmond Delaney     76
# Steve Ashton        84
# Sarah Bond          86
# Name: Vendedor, dtype: int64
